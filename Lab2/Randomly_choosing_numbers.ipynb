# %% [markdown]
# <a href="https://colab.research.google.com/github/povashraful/HBRS_2026_SS_Fundamentals_of_Artificial_Intelligence_for_Robotics/blob/main/Lab2/Randomly_choosing_numbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
rd = ["up", "down", "right", "left"]

# %%
import random

# %%
i=0
while i < 100:
  rd = ["up", "down", "right", "left"]
  random_choosing = random.choice(rd)
  print(random_choosing)
  i+=1
# Out:
# down
# right
# up
# down
# right
# right
# left
# right
# down
# up
# up
# down
# down
# down
# right
# right
# left
# right
# right
# down
# left
# right
# up
# right
# up
# up
# left
# down
# down
# down
# right
# down
# down
# right
# right
# left
# left
# down
# up
# down
# left
# right
# right
# left
# up
# right
# left
# up
# down
# right
# down
# right
# left
# right
# right
# left
# down
# left
# right
# down
# left
# left
# left
# left
# up
# left
# up
# right
# right
# down
# left
# right
# right
# down
# left
# right
# left
# down
# up
# right
# left
# down
# left
# up
# down
# left
# down
# left
# left
# left
# right
# up
# up
# down
# down
# down
# left
# right
# down
# up
